# %% [markdown]
# EU LOBBYING TRANSPARENCY -- PHASE II DS ANAALYSIS
# TEAM RAMM | Data Sources: LobbyFacts.eu + World Bank API

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import warnings
warnings.filterwarnings('ignore')

print('All imports successful!')
# Out:
# All imports successful!

# %%
## loads and looks at data 
 # Load LobbyFacts data
df = pd.read_csv('lobbyfacts_result__1_.csv')

print(f'Shape: {df.shape}')
print(f'\nColumns: {list(df.columns)}')
print(f'\nFirst 5 rows:')
df.head()
# Out:
# Shape: (16862, 11)
#
# Columns: ['Identification code', 'Name', 'Members FTE', 'Lobbying cost', 'Interest represented', 'Head office', 'EU office', 'EP passes on 2026-05-25', 'all EP passes', 'Meetings', 'Lobbyfacts URL']
#
# First 5 rows:
#   Identification code                                               Name  \
# 0      56047191389-84                                  Fleishman-Hillard
# 1      28666427835-74  Meta Platforms Ireland Limited and its various...
# 2     455076325447-19              TUMO Center for Creative Technologies
# 3     621015197613-26                                     GOPA-Tech GmbH
# 4      64879142323-90         CEFIC - European Chemical Industry Council
#
#    Members FTE  Lobbying cost  \
# 0        45.00       12730000
# 1        16.95       10000000
# 2        15.35       10000000
# 3         0.30       10000000
# 4        46.70       10000000
#
#                                 Interest represented Head office EU office  \
# 0                Advances interests of their clients     BELGIUM   BELGIUM
# 1  Promotes their own interests or the collective...     IRELAND   BELGIUM
# 2  Promotes their own interests or the collective...     ARMENIA   ARMENIA
# 3  Promotes their own interests or the collective...     GERMANY   GERMANY
# 4  Promotes their own interests or the collective...     BELGIUM   BELGIUM
#
#    EP passes on 2026-05-25  all EP passes  Meetings  \
# 0                     62.0          827.0      82.0
# 1                      8.0           81.0     283.0
# 2                      NaN            NaN       2.0
# 3                      NaN            NaN       3.0
# 4                     17.0          348.0     295.0
#
#                                       Lobbyfacts URL
# 0  https://www.lobbyfacts.eu/datacard/fleishman-h...
# 1  https://www.lobbyfacts.eu/datacard/meta-platfo...
# 2  https://www.lobbyfacts.eu/datacard/tumo-center...
# 3  https://www.lobbyfacts.eu/datacard/gopa-tech-g...
# 4  https://www.lobbyfacts.eu/datacard/cefic---eur...

# %%
## Will check for missing values 
print('=== Missing Values ===')
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(1)
print(pd.DataFrame({'missing_count': missing, 'missing_%': missing_pct}))

print('\n=== Basic Stats ===')
print(df['Lobbying cost'].describe())
# Out:
# === Missing Values ===
#                          missing_count  missing_%
# Identification code                  0        0.0
# Name                                 0        0.0
# Members FTE                          0        0.0
# Lobbying cost                        0        0.0
# Interest represented                 0        0.0
# Head office                          0        0.0
# EU office                            0        0.0
# EP passes on 2026-05-25          13746       81.5
# all EP passes                    12278       72.8
# Meetings                          9686       57.4
# Lobbyfacts URL                       0        0.0
#
# === Basic Stats ===
# count    1.686200e+04
# mean     1.076373e+05
# std      4.069298e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+04
# 75%      5.000000e+04
# max      1.273000e+07
# Name: Lobbying cost, dtype: float64

# %%
# Data Cleaning
df_clean = df.copy()

# Standardize country names from ALL CAPS to Title Case
df_clean['Head office'] = df_clean['Head office'].str.title().str.strip()
df_clean['EU office']   = df_clean['EU office'].str.title().str.strip()

# Fill missing numeric columns with 0, missing data will have zero instead 
df_clean['Meetings']                = df_clean['Meetings'].fillna(0)
df_clean['all EP passes']           = df_clean['all EP passes'].fillna(0)
df_clean['EP passes on 2026-05-25'] = df_clean['EP passes on 2026-05-25'].fillna(0)
df_clean['Members FTE']             = df_clean['Members FTE'].fillna(0)

df_clean = df_clean.drop(columns=['Identification code', 'Lobbyfacts URL'])

# Remove orgs with zero lobbying cost (no useful financial data)
# df_clean = df_clean[df_clean['Lobbying cost'] > 0]

print(f'Rows before cleaning: {len(df)}')
print(f'Rows after cleaning:  {len(df_clean)}')
print(f'\nSample countries after fix:')
print(df_clean['Head office'].value_counts().head(5))
# Out:
# Rows before cleaning: 16862
# Rows after cleaning:  16862
#
# Sample countries after fix:
# Head office
# Belgium    2656
# Germany    2110
# France     1564
# Italy      1072
# Spain      1047
# Name: count, dtype: int64

# %%
# Save cleaned data
df_clean.to_csv('lobbyfacts_cleaned.csv', index=False)
print('Saved! Open lobbyfacts_cleaned.csv in your Explorer to see it.')
# Out:
# Saved! Open lobbyfacts_cleaned.csv in your Explorer to see it.

# %%
df_clean.head(20)
# Out:
#                                                  Name  Members FTE  \
# 0                                   Fleishman-Hillard        45.00
# 1   Meta Platforms Ireland Limited and its various...        16.95
# 2               TUMO Center for Creative Technologies        15.35
# 3                                      GOPA-Tech GmbH         0.30
# 4          CEFIC - European Chemical Industry Council        46.70
# 5                                     INFINITE ORBITS         0.10
# 6                             Amazon Europe Core SARL         8.90
# 7                                          Grindr LLC         0.30
# 8                              FTI Consulting Belgium        54.50
# 9                                          Apple Inc.         8.40
# 10                            Burson Cohn & Wolfe SRL        27.50
# 11                              Microsoft Corporation         6.30
# 12                              Rud Pedersen Brussels        64.60
# 13                                             EUROFI         3.50
# 14                                   Insurance Europe        35.00
# 15                                           Bayer AG        20.00
# 16  European Federation of Pharmaceutical Industri...        13.40
# 17                                     BUSINESSEUROPE        31.00
# 18        Association for Financial Markets in Europe        17.00
# 19                                DGA Group Europe SA        65.75
#
#     Lobbying cost                               Interest represented  \
# 0        12730000                Advances interests of their clients
# 1        10000000  Promotes their own interests or the collective...
# 2        10000000  Promotes their own interests or the collective...
# 3        10000000  Promotes their own interests or the collective...
# 4        10000000  Promotes their own interests or the collective...
# 5        10000000  Promotes their own interests or the collective...
# 6         9000000  Promotes their own interests or the collective...
# 7         9000000  Promotes their own interests or the collective...
# 8         8495000                Advances interests of their clients
# 9         8000000  Promotes their own interests or the collective...
# 10        7025000                Advances interests of their clients
# 11        7000000  Promotes their own interests or the collective...
# 12        6705000                Advances interests of their clients
# 13        6000000  Promotes their own interests or the collective...
# 14        6000000  Promotes their own interests or the collective...
# 15        6000000  Promotes their own interests or the collective...
# 16        6000000  Promotes their own interests or the collective...
# 17        6000000  Promotes their own interests or the collective...
# 18        6000000  Promotes their own interests or the collective...
# 19        5740000                Advances interests of their clients
#
#        Head office      EU office  EP passes on 2026-05-25  all EP passes  \
# 0          Belgium        Belgium                     62.0          827.0
# 1          Ireland        Belgium                      8.0           81.0
# 2          Armenia        Armenia                      0.0            0.0
# 3          Germany        Germany                      0.0            0.0
# 4          Belgium        Belgium                     17.0          348.0
# 5           France         France                      0.0            0.0
# 6       Luxembourg     Luxembourg                     11.0           79.0
# 7    United States  United States                      0.0            0.0
# 8    United States        Belgium                     52.0          575.0
# 9    United States        Belgium                      9.0           82.0
# 10         Belgium        Belgium                     23.0          598.0
# 11   United States        Belgium                      8.0           80.0
# 12         Belgium        Belgium                     37.0          300.0
# 13          France         France                      0.0            0.0
# 14         Belgium        Belgium                     18.0          297.0
# 15         Germany        Belgium                      9.0          129.0
# 16      Luxembourg        Belgium                     15.0          119.0
# 17         Belgium        Belgium                     25.0          327.0
# 18  United Kingdom        Belgium                     11.0          100.0
# 19         Belgium        Belgium                     44.0          417.0
#
#     Meetings
# 0       82.0
# 1      283.0
# 2        2.0
# 3        3.0
# 4      295.0
# 5        0.0
# 6      213.0
# 7        3.0
# 8      104.0
# 9      175.0
# 10      15.0
# 11     284.0
# 12      48.0
# 13       0.0
# 14     142.0
# 15      99.0
# 16     174.0
# 17     595.0
# 18     119.0
# 19      37.0

# %%
# World Bank API - fetch country economic data
def fetch_world_bank(indicator, year=2022):
    url = f'https://api.worldbank.org/v2/country/all/indicator/{indicator}'
    params = {'date': year, 'format': 'json', 'per_page': 300}
    response = requests.get(url, params=params)
    data = response.json()
    
    if not isinstance(data, list) or len(data) < 2 or data[1] is None:
        print(f'  Warning: no data for {indicator}')
        return pd.DataFrame(columns=['country', 'iso2', indicator])
    
    records = []
    for entry in data[1]:
        if entry['value'] is not None:
            records.append({
                'country':  entry['country']['value'],
                'iso2':     entry['countryiso3code'],
                indicator:  entry['value']
            })
    
    df_wb = pd.DataFrame(records)
    print(f'  Fetched {len(df_wb)} countries for {indicator}')
    return df_wb

print('Fetching World Bank data...')
df_gdp       = fetch_world_bank('NY.GDP.MKTP.CD')
df_pop       = fetch_world_bank('SP.POP.TOTL')
df_inflation = fetch_world_bank('FP.CPI.TOTL.ZG')

# Merge all three
df_wb = df_gdp.merge(df_pop, on=['country', 'iso2'], how='outer')
df_wb = df_wb.merge(df_inflation, on=['country', 'iso2'], how='outer')

df_wb.rename(columns={
    'NY.GDP.MKTP.CD': 'gdp_usd',
    'SP.POP.TOTL':    'population',
    'FP.CPI.TOTL.ZG': 'inflation_rate'
}, inplace=True)

df_wb['gdp_per_capita'] = df_wb['gdp_usd'] / df_wb['population']

print(f'\nWorld Bank shape: {df_wb.shape}')
df_wb.head()
# Out:
# Fetching World Bank data...
#   Fetched 257 countries for NY.GDP.MKTP.CD
#   Fetched 265 countries for SP.POP.TOTL
#   Fetched 180 countries for FP.CPI.TOTL.ZG
#
# World Bank shape: (265, 6)
#                        country iso2       gdp_usd  population  inflation_rate  \
# 0                  Afghanistan  AFG  1.449724e+10    40578842       13.712102
# 1  Africa Eastern and Southern  AFE  1.228968e+12   731821393       10.883478
# 2   Africa Western and Central  AFW  1.063649e+12   497387180        7.949251
# 3                      Albania  ALB  1.901725e+10     2451636        6.725203
# 4                      Algeria  DZA  2.255816e+11    45477389        9.265516
#
#    gdp_per_capita
# 0      357.261153
# 1     1679.327622
# 2     2138.473153
# 3     7756.961887
# 4     4960.303343

# %%
# Merge LobbyFacts + World Bank
country_fixes = {
    'Czech Republic': 'Czechia',
    'South Korea': 'Korea, Rep.',
    'Russia': 'Russian Federation',
}

df_clean['country_merge'] = df_clean['Head office'].replace(country_fixes)

df_merged = df_clean.merge(df_wb, left_on='country_merge', right_on='country', how='left')

# Add lobbying to GDP ratio
df_merged['lobbying_gdp_ratio'] = df_merged['Lobbying cost'] / df_merged['gdp_usd'] * 1e9

matched = df_merged['gdp_usd'].notna().sum()
print(f'Total orgs: {len(df_merged)}')
print(f'Matched: {matched} ({matched/len(df_merged)*100:.1f}%)')

df_merged = df_merged.drop(columns=['Head office', 'Head Office', 'EU office', 'country_merge', 'iso2'])
df_merged.head(5)
# Out:
# Total orgs: 16862
# Matched: 16515 (97.9%)
#                                                 Name  Members FTE  \
# 0                                  Fleishman-Hillard        45.00
# 1  Meta Platforms Ireland Limited and its various...        16.95
# 2              TUMO Center for Creative Technologies        15.35
# 3                                     GOPA-Tech GmbH         0.30
# 4         CEFIC - European Chemical Industry Council        46.70
#
#    Lobbying cost                               Interest represented  \
# 0       12730000                Advances interests of their clients
# 1       10000000  Promotes their own interests or the collective...
# 2       10000000  Promotes their own interests or the collective...
# 3       10000000  Promotes their own interests or the collective...
# 4       10000000  Promotes their own interests or the collective...
#
#    EP passes on 2026-05-25  all EP passes  Meetings  country       gdp_usd  \
# 0                     62.0          827.0      82.0  Belgium  5.910858e+11
# 1                      8.0           81.0     283.0  Ireland  5.483418e+11
# 2                      0.0            0.0       2.0  Armenia  1.951351e+10
# 3                      0.0            0.0       3.0  Germany  4.201022e+12
# 4                     17.0          348.0     295.0  Belgium  5.910858e+11
#
#    population  inflation_rate  gdp_per_capita  lobbying_gdp_ratio
# 0  11680210.0        9.597512    50605.749668        21536.637082
# 1   5212836.0        7.829457   105190.685953        18236.800657
# 2   2969200.0        8.640911     6571.974455       512465.556756
# 3  83177813.0        6.872574    50506.517964         2380.373323
# 4  11680210.0        9.597512    50605.749668        16918.018132
